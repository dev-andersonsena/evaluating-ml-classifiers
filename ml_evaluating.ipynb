# %%
# !pip install numpy==2.2.0
# !pip install pandas==2.2.3
# !pip install scikit-learn==1.6.0
# !pip install matplotlib==3.9.3
# !pip install seaborn==0.13.2
# Out:
# Collecting numpy==2.2.0
#   Downloading numpy-2.2.0-cp311-cp311-win_amd64.whl (12.9 MB)
#      ---------------------------------------- 12.9/12.9 MB 4.5 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.2.0
# [notice] A new release of pip available: 22.3.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pandas==2.2.3
#   Downloading pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
#      ---------------------------------------- 11.6/11.6 MB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.2 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from pandas==2.2.3) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from pandas==2.2.3) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Downloading pytz-2026.2-py2.py3-none-any.whl (510 kB)
#      -------------------------------------- 510.1/510.1 kB 4.6 MB/s eta 0:00:00
# Collecting tzdata>=2022.7
#   Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
#      -------------------------------------- 349.3/349.3 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.17.0)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2026.2 tzdata-2026.2
# [notice] A new release of pip available: 22.3.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting scikit-learn==1.6.0
#   Downloading scikit_learn-1.6.0-cp311-cp311-win_amd64.whl (11.1 MB)
#      ---------------------------------------- 11.1/11.1 MB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.5 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from scikit-learn==1.6.0) (2.2.0)
# Collecting scipy>=1.6.0
#   Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl (36.6 MB)
#      ---------------------------------------- 36.6/36.6 MB 4.3 MB/s eta 0:00:00
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#      -------------------------------------- 309.1/309.1 kB 4.8 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.6.0 scipy-1.17.1 threadpoolctl-3.6.0
# [notice] A new release of pip available: 22.3.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting matplotlib==3.9.3
#   Downloading matplotlib-3.9.3-cp311-cp311-win_amd64.whl (7.8 MB)
#      ---------------------------------------- 7.8/7.8 MB 3.6 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
#      -------------------------------------- 225.2/225.2 kB 4.6 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.63.0-cp311-cp311-win_amd64.whl (2.4 MB)
#      ---------------------------------------- 2.4/2.4 MB 5.2 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.5.0-cp311-cp311-win_amd64.whl (73 kB)
#      ---------------------------------------- 73.5/73.5 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from matplotlib==3.9.3) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from matplotlib==3.9.3) (26.2)
# Collecting pillow>=8
#   Downloading pillow-12.2.0-cp311-cp311-win_amd64.whl (7.1 MB)
#      ---------------------------------------- 7.1/7.1 MB 4.9 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#      -------------------------------------- 122.8/122.8 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from matplotlib==3.9.3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.9.3) (1.17.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.9.3 pillow-12.2.0 pyparsing-3.3.2
# [notice] A new release of pip available: 22.3.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting seaborn==0.13.2
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from seaborn==0.13.2) (2.2.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from seaborn==0.13.2) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from seaborn==0.13.2) (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (12.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from pandas>=1.2->seaborn==0.13.2) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from pandas>=1.2->seaborn==0.13.2) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\anderson\documents\ibm\evaluating-ml-classifiers\ambientevirtual\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.17.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip available: 22.3.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = load_breast_cancer()
X, y = data.data, data.target
labels = data.target_names
feature_names = data.feature_names

# %%
print(data.DESCR)

# %%
print(data.target_names)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Add Gaussian noise to the data set
np.random.seed(42)  # For reproducibility
noise_factor = 0.5 # Adjust this to control the amount of noise
X_noisy = X_scaled + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=X.shape)

# Load the original and noisy data sets into a DataFrame for comparison and visualization
df = pd.DataFrame(X_scaled, columns=feature_names)
df_noisy = pd.DataFrame(X_noisy, columns=feature_names)

# %%
# Display the first few rows of the standardized original and noisy data sets for comparison
print("Original Data (First 5 rows):")
df.head()

# %%
print("\nNoisy Data (First 5 rows):")
df_noisy.head()

# %%
Histograms

# %%
plt.figure(figsize=(12, 6))

# Original Feature Distribution (Noise-Free)
plt.subplot(1, 2, 1)
plt.hist(df[feature_names[5]], bins=20, alpha=0.7, color='blue', label='Original')
plt.title('Original Feature Distribution')
plt.xlabel(feature_names[5])
plt.ylabel('Frequency')

# Noisy Feature Distribution
plt.subplot(1, 2, 2)
plt.hist(df_noisy[feature_names[5]], bins=20, alpha=0.7, color='red', label='Noisy') 
plt.title('Noisy Feature Distribution')
plt.xlabel(feature_names[5])  
plt.ylabel('Frequency')

plt.tight_layout()  # Ensures proper spacing between subplots
plt.show()

# %%
Plots

# %%
plt.figure(figsize=(12, 6))
plt.plot(df[feature_names[5]], label='Original',lw=3)
plt.plot(df_noisy[feature_names[5]], '--',label='Noisy',)
plt.title('Scaled feature comparison with and without noise')
plt.xlabel(feature_names[5])
plt.legend()
plt.tight_layout()
plt.show()

# %%
Scatterplot

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df[feature_names[5]], df_noisy[feature_names[5]],lw=5)
plt.title('Scaled feature comparison with and without noise')
plt.xlabel('Original Feature')
plt.ylabel('Noisy Feature')
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X_noisy, y, test_size=0.3, random_state=42)
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the models
knn = KNeighborsClassifier(n_neighbors=5)
svm = SVC(kernel='linear', C=1, random_state=42)

# Fit the models to the training data
knn.fit(X_train, y_train)
svm.fit(X_train, y_train)

# %%
y_pred_knn = knn.predict(X_test)
y_pred_svm = svm.predict(X_test)

# %%
print(f"KNN Testing Accuracy: {accuracy_score(y_test, y_pred_knn):.3f}")
print(f"SVM Testing Accuracy: {accuracy_score(y_test, y_pred_svm):.3f}")

print("\nKNN Testing Data Classification Report:")
print(classification_report(y_test, y_pred_knn))

print("\nSVM Testing Data Classification Report:")
print(classification_report(y_test, y_pred_svm))

# %%
conf_matrix_knn = confusion_matrix(y_test, y_pred_knn)
conf_matrix_svm = confusion_matrix(y_test, y_pred_svm)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.heatmap(conf_matrix_knn, annot=True, cmap='Blues', fmt='d', ax=axes[0],
            xticklabels=labels, yticklabels=labels)

axes[0].set_title('KNN Testing Confusion Matrix')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

sns.heatmap(conf_matrix_svm, annot=True, cmap='Blues', fmt='d', ax=axes[1],
            xticklabels=labels, yticklabels=labels)
axes[1].set_title('SVM Testing Confusion Matrix')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %%
y_pred_train_knn = knn.predict(X_train)
y_pred_train_svm = svm.predict(X_train)

# %%
print(f"KNN Training Accuracy: {accuracy_score(y_train, y_pred_train_knn):.3f}")
print(f"SVM Training Accuracy: {accuracy_score(y_train, y_pred_train_svm):.3f}")

print("\nKNN Training Classification Report:")
print(classification_report(y_train, y_pred_train_knn))

print("\nSVM Training Classification Report:")
print(classification_report(y_train, y_pred_train_svm))

# %%
conf_matrix_knn = confusion_matrix(y_train, ...)
conf_matrix_svm = confusion_matrix(y_train, ...)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns....(..., annot=True, cmap='Blues', fmt='d', ax=axes[0],
            xticklabels=labels, yticklabels=labels)

axes[0].set_title('KNN Training Confusion Matrix')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

sns.heatmap(..., annot=True, cmap='Blues', fmt='d', ax=axes[1],
            xticklabels=labels, yticklabels=labels)
axes[1].set_title('SVM Training Confusion Matrix')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

plt.tight_layout()
plt.show()
